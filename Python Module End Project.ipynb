# %% [markdown]
# ## Importing necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ### * Replacing the 'Height' column with random values between 150 and 180

# %%
df['Height'] = np.random.randint(150, 181, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     151     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     178     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     158     256
# 456    Jeff Withey       Utah Jazz      24        C   26     162     231
# 457       Priyanka       Utah Jazz      34        C   25     180     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### * Ensuring data consistency

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df['College'].fillna('Unknown', inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     151     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     178     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     158     256
# 456    Jeff Withey       Utah Jazz      24        C   26     162     231
# 457       Priyanka       Utah Jazz      34        C   25     180     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#To check if there are any duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# ### 1. The distribution of employees across each team and calculating the percentage split

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
team_distribution = df['Team'].value_counts()
total_employees = len(df)
team_percentage = (team_distribution / total_employees) * 100
team_percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
plt.figure(figsize=(10, 6))
team_percentage.plot(kind='bar', color='teal')
plt.xlabel('Team')
plt.ylabel('Percentage of Employees %')
plt.title('Team Distribution')
plt.show()

# %% [markdown]
# ### 2. Segregate employees based on their positions within the company.

# %%
employees = df.groupby('Position')['Name'].apply(list)
for Position, Names in employees.items():
    print(f"employees in {Position} position:")
    for name in Names:
     print(name)
    print("\n")
# Out:
# employees in C position:
# Kelly Olynyk
# Jared Sullinger
# Tyler Zeller
# Brook Lopez
# Henry Sims
# Robin Lopez
# Kevin Seraphin
# Joel Embiid
# Jahlil Okafor
# Bismack Biyombo
# Lucas Nogueira
# Jonas Valanciunas
# Andrew Bogut
# Festus Ezeli
# Marreese Speights
# Cole Aldrich
# DeAndre Jordan
# Tarik Black
# Roy Hibbert
# Robert Sacre
# Tyson Chandler
# Alex Len
# Alan Williams
# Willie Cauley-Stein
# DeMarcus Cousins
# Kosta Koufos
# Pau Gasol
# Joakim Noah
# Sasha Kaun
# Timofey Mozgov
# Tristan Thompson
# Joel Anthony
# Aron Baynes
# Andre Drummond
# Jordan Hill
# Ian Mahinmi
# Greg Monroe
# Miles Plumlee
# JaVale McGee
# Salah Mejri
# Zaza Pachulia
# Dwight Howard
# Josh Smith
# Marc Gasol
# Alexis Ajinca
# Omer Asik
# Kendrick Perkins
# Matt Bonner
# Boris Diaw
# Tim Duncan
# Boban Marjanovic
# Al Horford
# Tiago Splitter
# Walter Tavares
# Al Jefferson
# Frank Kaminsky III
# Cody Zeller
# Hassan Whiteside
# Dewayne Dedmon
# Nikola Vucevic
# Marcin Gortat
# JJ Hickson
# ...

# %%
position_distribution = df['Position'].value_counts()
position_distribution
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(y='Position', data=df)
plt.title('Position Distribution')
plt.show()

# %% [markdown]
# ### 3. Finding the predominant age group among employees.

# %%
df['Age Group'] = df['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 and above')))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     151     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     178     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     158     256
# 456    Jeff Withey       Utah Jazz      24        C   26     162     231
# 457       Priyanka       Utah Jazz      34        C   25     180     231
#
#                College        Salary Age Group
# ...

# %%
df['Age Group'].value_counts()
# Out:
# Age Group
# 20-25           198
# 26-30           167
# 31-35            68
# 36 and above     25
# Name: count, dtype: int64

# %%
df['Age Group'].value_counts().plot(kind='bar', figsize=(8, 6), color='teal')
plt.title("Age Group Distribution of Employees")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# ### 4. Discovering team and position having the highest salary expenditure.

# %%
team_salary = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)
position_salary =df.groupby('Position')['Salary'].sum().sort_values(ascending=False)
team_salary,position_salary
# Out:
# (Team
#  Cleveland Cavaliers       1.118227e+08
#  Memphis Grizzlies         9.588676e+07
#  Los Angeles Clippers      9.485464e+07
#  Oklahoma City Thunder     9.376530e+07
#  Miami Heat                9.218361e+07
#  Golden State Warriors     8.886900e+07
#  Chicago Bulls             8.678338e+07
#  San Antonio Spurs         8.444273e+07
#  New Orleans Pelicans      8.275077e+07
#  Charlotte Hornets         7.834092e+07
#  Washington Wizards        7.632864e+07
#  Houston Rockets           7.528302e+07
#  New York Knicks           7.330390e+07
#  Atlanta Hawks             7.290295e+07
#  Los Angeles Lakers        7.177043e+07
#  Sacramento Kings          7.168367e+07
#  Dallas Mavericks          7.119873e+07
#  Toronto Raptors           7.111761e+07
#  Milwaukee Bucks           6.960352e+07
#  Detroit Pistons           6.716826e+07
#  Indiana Pacers            6.675183e+07
#  Denver Nuggets            6.495590e+07
#  Minnesota Timberwolves    6.454367e+07
# ...

# %%
highest_salary_team = team_salary.idxmax()
highest_salary_position = position_salary.idxmax()

print(f"Team with the highest salary: {highest_salary_team}")
print(f"Position with the highest salary: {highest_salary_position}")
# Out:
# Team with the highest salary: Cleveland Cavaliers
# Position with the highest salary: C

# %%
team_salary.plot(kind='bar', figsize=(8, 6))
plt.title("Total Salary Expenditure by Team")
plt.ylabel("Total Salary")
plt.show()

position_salary.plot(kind='bar', figsize=(8, 6))
plt.title("Total Salary Expenditure by Position")
plt.ylabel("Total Salary")
plt.show()

# %% [markdown]
# ### 5. Investigate if there's any correlation between age and salary, and representing it visually.

# %%
Correlation = df['Salary'].corr(df['Age'])
print("The correlation b/w Salary and Age is ",Correlation)
# Out:
# The correlation b/w Salary and Age is  0.21116954917686365

# %%
sns.scatterplot(x="Age",y="Salary",data=df,hue="Age",palette="cool")
plt.title("Correlation b/w Salary and Age")
plt.ylabel("Salary")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# ### Data Story:
#
# #### 1. Team Distribution: Examine how employees are split among various teams to identify any potential disparities or areas needing additional funding.In this case, the "New Orleans Pelicans" have the highest distribution percentage at 4.148472, while both the Orlando Magic and Minnesota Timberwolves have the lowest distribution percentages at 3.056769.
#
#
# #### 2. Segregation of Positions: Analyze the different positions and their allocation within the organization. Here, the SG position has the highest distribution with 102 workers, while the C position has the lowest distribution with 79 workers.
#
#  #### 3.  Age Group: Determine the most common age group. From this, we can clearly see that the majority of workers are in the 20–25 and 26–30 age ranges.
#
# #### 4.  Salary Expenditure: Analyze salary expenditures by team and position to optimize budget allocation. The Cleveland Cavaliers have the highest salary expenditure, while workers in the C position have the highest salaries.highest salary and the workers in the position C having the highest salarey
#
# ####  5. Age-Salary Correlation: Interpret the correlation between age and salary to understand potential salary trends and disparities.ties.
